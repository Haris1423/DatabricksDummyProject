# %% [markdown]
# ![image_1773504750449.png](./image_1773504750449.png "image_1773504750449.png")

# %% [markdown]
# ![image_1773504767041.png](./image_1773504767041.png "image_1773504767041.png")

# %% [markdown]
# ![image_1773505027595.png](./image_1773505027595.png "image_1773505027595.png")

# %%
Go To COMPUTE > APPS >
