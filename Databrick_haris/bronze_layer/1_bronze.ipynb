# %% [markdown]
# # Volume
# * Databricks will create a main folder in which we have volumes

# %%
# %sql 
CREATE databricksharis.bronze.bronze_volume

# %% [markdown]
# ### Create a directory and upload file there

# %%
# %sql
--- AS CSV DOESN'T HAVE A SCHEMA--- WE ARE GOVERNING THE NON TABULAR DATA
SELECT * FROM csv.`/Volumes/databricksharis/bronze/bronze_volume/sales/`

# %% [markdown]
# # DB UTILS

# %%
dbutils.help()

# %%
dbutils.help("fs")

# %%
dbutils.fs.ls("/Volumes/adb_training_haris/bronze/bronze_volume/sales/")

# %% [markdown]
# ## create a folder in a directory

# %%
dbutils.fs.mkdirs("/Volumes/databricksharis/bronze/bronze_volume/customers/")

# %% [markdown]
# #  copy files

# %%
dbutils.fs.cp("/Volumes/adb_training_haris/bronze/bronze_volume/sales/", "/Volumes/adb_training_haris/bronze/bronze_volume/customer/",True)

# %% [markdown]
# # Remove files

# %%
dbutils.fs.rm("/Volumes/adb_training_haris/bronze/bronze_volume/customer/fact_sales.csv",True)

# %% [markdown]
# # CREATE FILES

# %%
dbutils.fs.put("/Volumes/adb_training_haris/bronze/bronze_volume/customer/test.txt","Hello Haris How are you?",True)

# %%
dbutils.fs.put("/Volumes/adb_training_haris/bronze/bronze_volume/customer/test.py","print(Hello Haris How are you?)",True)

# %%
all_items= dbutils.fs.ls("/Volumes/adb_training_haris/bronze/bronze_volume/customer/")

# %%
file_names = [x.name for x in all_items]
file_names

# %% [markdown]
# ## Remove Files

# %%
for x in file_names:
  dbutils.fs.rm("/Volumes/adb_training_haris/bronze/bronze_volume/customer/{x}",True)

# %% [markdown]
# # Widgets

# %%
dbutils.widgets.text("par1"," ")

# %%
par_value = dbutils.widgets.get("par1")
par_value

# %%
dbutils.widgets.text("Har", "")

# %%
dbutils.widgets.get("Har")
