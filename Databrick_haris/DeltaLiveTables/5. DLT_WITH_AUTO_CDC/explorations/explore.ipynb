# %%
# %sql 
create TABLE adb_training_haris.bronze.products(
  product_id INT,
  product_name STRING,
  process_date TIMESTAMP
)

# %%
# %sql
insert into adb_training_haris.bronze.products values (1,'honey',current_timestamp()),(2,'milk', current_timestamp()),(3,'bread',current_timestamp())

# %%
# %sql
insert into adb_training_haris.bronze.products values (1,'honey',current_timestamp()),(2,'milk', current_timestamp()),(3,'multigrainBread',current_timestamp()),(4,'mint',current_timestamp())

# %%
# %sql
select * from adb_training_haris.dlt_schema.scd1_table

# %%
# %sql
select * from adb_training_haris.dlt_schema.scd2_table

# %%
# %sql
select * from adb_training_haris.dlt_schema.scd3_table

# %%
# %sql
insert into adb_training_haris.bronze.products values (1,'honey',current_timestamp()),(2,'milk', current_timestamp()),(3,'WheatgrainBread',current_timestamp()),(4,'mint',current_timestamp())

# %%
# %sql
select * from adb_training_haris.dlt_schema.scd3_table
