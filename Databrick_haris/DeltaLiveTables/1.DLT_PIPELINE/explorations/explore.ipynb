# %%
df= spark.read.table("databricksharis.silver.sales_enr")

# %%
display(df)

# %%
# %sql
--create a demo table for Auto cdc

create table databricksharis.bronze.source(
  product_id string,
  product_name string,
  processdate timestamp
)

# %%
# %sql 
INSERT INTO databricksharis.bronze.source values
(1, "Honey", current_timestamp()),
(2, "milk", current_timestamp()),
(3, "bread", current_timestamp())

# %%
# %sql
select * from databricksharis.dlt_schema.scd1_table

# %%
# %sql
select * from databricksharis.dlt_schema.scd2_table

# %% [markdown]
# ## insert new values in the table

# %%
# %sql 
INSERT INTO databricksharis.bronze.source values
(1, "Honey", current_timestamp()),
(2, "milk", current_timestamp()),
(3, "multigrainBread", current_timestamp()),
(4, "mint", current_timestamp())

# %% [markdown]
# ### RUN Pipeline now

# %%
# %sql
select * from databricksharis.dlt_schema.scd1_table

# %%
# %sql
select * from databricksharis.dlt_schema.scd2_table

# %% [markdown]
# %md
# ### scd3 running after that except_column_list otherwise it creates multiple entries for existing du to different process date, it removes the old due to sequence by column

# %%
# %sql
select * from databricksharis.dlt_schema.scd3_table

# %% [markdown]
# ### Add some new records

# %%
# %sql 
INSERT INTO databricksharis.bronze.source values
(1, "Honey", current_timestamp()),
(2, "milk", current_timestamp()),
(3, "wholeWheatBread", current_timestamp()),
(4, "mint", current_timestamp())

# %% [markdown]
# ###  Run the pipeline and check scd3

# %%
# %sql
select * from databricksharis.dlt_schema.scd3_table

---- 1, 2, 4 duplicate data be removed by sequence column, and process data is excepted

# %%
# %sql
select * from databricksharis.dlt_schema.scd1_table
