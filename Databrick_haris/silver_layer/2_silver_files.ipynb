# %% [markdown]
# Involve some files that we used in our workspace
# Create a file .txt

# %% [markdown]
# ### **Text files**

# %%
with open('/Workspace/Users/harisbhat14231@gmail.com/Databrick_haris/silver_layer/file.txt', "r") as f:
    content = f.read()

print(content)

# %%
with open('/Workspace/Users/harisbhat14231@gmail.com/Databrick_haris/silver_layer/new_file.txt', "w") as f :
    f.write("Hello Haris Bhat!")

# %%
with open('/Workspace/Users/harisbhat14231@gmail.com/Databrick_haris/silver_layer/new_file.txt', "r") as f:
    content = f.read()

print(content)

# %% [markdown]
# ### **Python Files**

# %%
with open('/Workspace/Users/harisbhat14231@gmail.com/Databrick_haris/silver_layer/new_file.py', "w") as f :
    f.write("my_secret = 123")

# %% [markdown]
# Need to store credentials when we worked with API , we can leverage this py file

# %% [markdown]
# ### **Python Files**

# %%
import new_file

# %%
new_file.my_secret

# %% [markdown]
# ### **JSON/MAPPING FILES**

# %% [markdown]
# Create a file mapping.json file
# { id : [1, 2, 3, 4, 5],
# "name" : ["aa, "bb", "cc", "dd", "ee"]}
#
# Here Pandas outperforms the pyspark , as it works well with small files

# %%
import pandas as pd 
df = pd.read_json("/Workspace/Users/harisbhat14231@gmail.com/Databrick_haris/silver_layer/mappings.json")
df.head()

# %% [markdown]
# ### **Converted into to a Pyspark dataframe**

# %%
df_pysaprk = spark.createDataFrame(df)

display(df_pysaprk)
