-- %%
----Query is different as we have not used this query, first re run the query again and then we can now check in query history, after checking query profile is not available in the last refresh within in the mili seconds as it took data from cached 
select * from customers_enr
where location = 'Port Joseph'
