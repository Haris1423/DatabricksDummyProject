-- %%
--select * from products_enr
--Where category = :para_category

--SELECT IDENTIFIER(:para_cat), IDENTIFIER(:para_prodId)
--FROM products_enr


---QUERY SNIPPETS
select * from products_enr
where category= 'Toys' AND price > 100
