# %% [markdown]
# With the Help of Data Governance you actually maintaing the solution and scale it later
# Data Governance will tell us who are using the Data and all.
# ![image_1773418247618.png](./image_1773418247618.png "image_1773418247618.png")
#
# it's made up of so many elements

# %% [markdown]
# ### 1 . Data Discoverability :
# Upstream, downstream, what's update and all comes in this
# Go to Catalog > Catalog Explorer
#
# - Check Permissions
# - Check Policies
# - Check Workspaces

# %% [markdown]
# ## From Table we can see the details
# ![image_1773418544497.png](./image_1773418544497.png "image_1773418544497.png")

# %% [markdown]
# ### 2. DATA QUALITY :
# in DLT we use Quality or in Normal DB we use Constraints
#
# - In DLT we can create these quality Monitoring to check whether it follows the rules
# ![image_1773418622839.png](./image_1773418622839.png "image_1773418622839.png")

# %% [markdown]
# ### 3. DATA COLLABRATION :
# WE CAN SHARE THE CATALOG WHEN IT'S ATTACHED TO SAME WORKSPACE,
# BUT IF WE HAVE TWO METASTORE, WE CAN USE DELTA SHARE ,
# TWO TYPES OF SHARING
# 1. DELTA SHARING DATABRICKS TO DATABRICKS : WE HAVE TO REGISTER THE SHARIMG CATALOG AS FOREIGN CATALOG IN OTHER WORKSPACE, WILL CREATE A RECEIPENT BY PROVIDING THE METASTORE ID OF WITH WE SHARE
# 2. OPEN SOURCE PROTOCAL
# ![image_1773418794381.png](./image_1773418794381.png "image_1773418794381.png")

# %% [markdown]
# ### 4. DATA ACESS CONTROL :
#
# HIDING THE DATA FROM USERS
# ADMIN SEES ALL THE DATA
# USERS SHOULD NOT SEE ALL THE DATA  LIKE PII , SALARY
