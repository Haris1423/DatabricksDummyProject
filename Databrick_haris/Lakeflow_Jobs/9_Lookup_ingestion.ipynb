# %%
my_array = [
    {
        "parent_folder_name" : "raw", 
        "folder_name" : "customers"
    },
    {
        "parent_folder_name" : "raw", 
        "folder_name" : "sales"
    },
    {
        "parent_folder_name" : "raw", 
        "folder_name" : "products"
    },
    {
        "parent_folder_name" : "raw", 
        "folder_name" : "stores"
    }
]

# %%
dbutils.jobs.taskValues.set("my_array", my_array)

# %% [markdown]
# Add a condition also

# %%
length_array = len(my_array)

# %%
dbutils.jobs.taskValues.set("length_array", length_array)
