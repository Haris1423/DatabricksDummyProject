# %%
dbutils.widgets.text("sql_output", '')

# %%
sql_output_text = dbutils.widgets.get("sql_output")
if sql_output_text:
  print(sql_output_text)

# %% [markdown]
# ### We need list instead of text from the parameter

# %%
from pyspark.sql.functions import * 

sql_output_list = eval(sql_output_text)
sql_output_list

# %%
import json

# Assuming sql_output_text contains the JSON string
cleaned_text = sql_output_text.rstrip('}')
sql_output_list = json.loads(cleaned_text)

sql_output_list
