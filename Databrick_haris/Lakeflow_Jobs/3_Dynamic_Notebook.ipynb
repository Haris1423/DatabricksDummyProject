# %% [markdown]
# ![image_1773073969204.png](./image_1773073969204.png "image_1773073969204.png")
#
# using output as paramter for another Notebook to run
#
# ![image_1773074013577.png](./image_1773074013577.png "image_1773074013577.png")

# %% [markdown]
# ![image_1773074086661.png](./image_1773074086661.png "image_1773074086661.png")

# %%
dbutils.widgets.text("Param1","")

# %%
para1_value = dbutils.widgets.get("Param1")
para1_value

# %% [markdown]
# Let's create a dynamic sql file
# ### Get Values

# %%
var2 = dbutils.jobs.taskValues.get(
    taskKey='Lookup', #task in job
    key='lookup_output'
)
print(var2)
