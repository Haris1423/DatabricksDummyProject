# %%
dbutils.widgets.text("sql_row", "")
dbutils.widgets.text("sql_col", "")

# %%
var1 = dbutils.widgets.get("sql_row")
var2 = dbutils.widgets.get("sql_col")

print(var1)

# %% [markdown]
# Will get dictionary in var1 , in this dictionary we get the category as we have added in param in pipeline

# %%
print(var2)
