# %% [markdown]
# ![image_1773071164503.png](./image_1773071164503.png "image_1773071164503.png")
#
#
#
#
# ![image_1773071260791.png](./image_1773071260791.png "image_1773071260791.png")

# %% [markdown]
# ### create a volume firstand then create a folder raw in it as we wanted to created lakeflow jobs from python files then next sql files

# %%
# %sql
# CREATE VOLUME databricksharis.bronze.jobvolume

# %%
df = spark.read.format("csv")\
    .option("header", True)\
    .option("inferSchema", True)\
    .load("/Volumes/databricksharis/bronze/bronze_volume/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("/Volumes/databricksharis//bronze/jobvolume/raw/stores/")

# %% [markdown]
# Now create a SQL files after that , we can use queries , but in advance sql out performs
