# %% [markdown]
# First we'll delete the stores directory in raw in jobvolume,
#
# Need to do the task for all the folders , We can use parametrs of folders and pass the parameters
#
# For that we created a notebook Lookup ingestion
#
# then create a new job

# %%
#source : BRONZE VOLUME 
#Need to copy data and folder from bronze_volume in the Jobvolume raw folder (destination)

# %%
dbutils.widgets.text("folder_name","")
dbutils.widgets.text("parent_folder_name","")

# %%
folder_name = dbutils.widgets.get("folder_name")
parent_folder_name = dbutils.widgets.get("parent_folder_name")

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(f"/Volumes/databricksharis/bronze/bronze_volume/{folder_name}/")

# %%
df.write.format("delta").mode("overwrite").\
    save(f"/Volumes/databricksharis/bronze/jobvolume/{parent_folder_name}/{folder_name}/")
